# %% [markdown]
# ## Demo Pendulum using DDPG agent (using Stable-baselines 3 RL library)
#  - Demonstrates the [Pendulum problem](https://gymnasium.farama.org/environments/classic_control/pendulum/)
#  - The inverted pendulum swingup problem is based on the classic problem in control theory. The system consists of a pendulum attached at one end to a fixed point, and the other end being free. The pendulum starts in a random position and the goal is to apply torque on the free end to swing it into an upright position, with its center of gravity right above the fixed point.
#  - The use of a DDPG agent is used to balance the Cart-pole
#  - Steps of the solution include:
#    - Step 1: Add imports
#    - Step 2: Instantiate the environment and the DDPG agent
#    - Step 3: Train the DDPG RL agent
#    - Step 4: Plot the reward curves of the trained RL agent
#    - Step 5: Evaluate the trained DDPG RL agent

# %% [markdown]
# #### Step 1: Add imports

# %%
import gymnasium as gym
import sys

sys.path.insert(1, "../")

import src.main.configs.global_configs as configs
import src.main.configs.global_configs as configs
from src.main.utility.utils import Helpers
from src.main.rl_algorithms.train_evaluate_test.ddpg_algorithm import DDPGTrainAlgorithm
from src.main.rl_algorithms.hyper_parameter_tuning.dqn_hyper_parameter_tuning import DQNHyperParameterTuning
from src.main.utility.enum_types import RLAgorithmType
from src.main.utility.chart_results import ChartResults

# %% [markdown]
# #### Step 2: Instantiate the environment and the DDPG agent

# %%
pendulum_name = configs.PENDULUM_PROBLEM_NAME
env = gym.make(pendulum_name, render_mode=configs.RENDER_MODE)
rl_algorithm = RLAgorithmType.ddpg
ddpg_agent = DDPGTrainAlgorithm(env)
# Out:
# 2025-06-10 21:29:06,654 - INFO - ddpg_algorithm.py:__init__ - : Start of Reinforcement learning for environment: PENDULUM-V1 in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\ddpg_algorithm.py:47
# 2025-06-10 21:29:06,655 - INFO - ddpg_algorithm.py:__init__ - : This RL environment uses a DDPG RL algorithm agent in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\ddpg_algorithm.py:48
# 2025-06-10 21:29:06,657 - INFO - base_algorithms.py:hyper_parameters - : Training is using non-tuned hyperparameters... in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\base_algorithms.py:119
# 2025-06-10 21:29:06,658 - INFO - base_algorithms.py:hyper_parameters - : Hyperparameters are:
# {'gamma': 0.9999, 'learning_rate': 0.0005, 'batch_size': 128, 'policy_kwargs': {'net_arch': {'pi': [64, 64], 'qf': [64, 64]}}} in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\base_algorithms.py:120

# %% [markdown]
# #### Step 3: Train the DDPG RL agent

# %%
ddpg_agent.train()
# Out:
# 2025-06-10 21:29:09,172 - INFO - save_on_base_reward_callback.py:_init_callback - : Saving trained RL model to ./logs/Pendulum-v1_ddpg\best_model in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:45
# 2025-06-10 21:29:13,453 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -1455.20
# 2025-06-10 21:29:18,152 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 2000
# Best mean reward: -1455.20 - Last mean reward per episode: -1447.09
# 2025-06-10 21:29:23,386 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 3000
# Best mean reward: -1447.09 - Last mean reward per episode: -1331.67
# 2025-06-10 21:29:28,428 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 4000
# Best mean reward: -1331.67 - Last mean reward per episode: -1275.28
# 2025-06-10 21:29:33,986 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 5000
# Best mean reward: -1275.28 - Last mean reward per episode: -1195.12
# 2025-06-10 21:29:40,789 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 6000
# Best mean reward: -1195.12 - Last mean reward per episode: -1066.47
# 2025-06-10 21:29:56,713 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 7000
# Best mean reward: -1066.47 - Last mean reward per episode: -938.11
# 2025-06-10 21:30:13,650 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 8000
# Best mean reward: -938.11 - Last mean reward per episode: -877.12
# 2025-06-10 21:30:30,757 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 9000
# Best mean reward: -877.12 - Last mean reward per episode: -793.11
# 2025-06-10 21:30:47,615 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/Pendulum-v1_ddpg\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\pendulum\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 10000
# Best mean reward: -793.11 - Last mean reward per episode: -733.60
# Eval num_timesteps=10000, episode_reward=-100.53 +/- 87.94
# Episode length: 200.00 +/- 0.00
# New best mean reward!
# Stopping training because the mean reward -100.53  is above the threshold -200

# %% [markdown]
# #### Step 4: Plot the reward curves of the trained RL agent

# %%
rewards = Helpers.getSmoothedAverageRewards(
    env_name=pendulum_name,
    rl_algo_name=rl_algorithm.name
)
ChartResults.plotRewardCurve(rewards, window_size=200)

# %% [markdown]
# #### Step 5: Evaluate the trained DDPG RL agent

# %%
eval_env = gym.make(pendulum_name, render_mode="human")
eval_rewards = ddpg_agent.evaluate(env=eval_env)
