# %% [markdown]
# ## Demo Frozen-lake using Q-Learning agent
#  - Demonstrates the Frozen-lake problem
#  - Frozen lake involves crossing a [frozen lake](https://gymnasium.farama.org/environments/toy_text/frozen_lake/) from start to goal without falling into any holes by walking over the frozen lake. The player may not always move in the intended direction due to the slippery nature of the frozen lake.
#  - The game starts with the player at location [0,0] of the frozen lake grid world with the goal located at far extent of the world e.g. [3,3] for the 4x4 environment.Holes in the ice are distributed in set locations when using a pre-determined map or in random locations when a random map is generated.
#  - The use of a DQN agent is used to balance the Cart-pole
#  - Steps of the solution include:
#    - Step 1: Add imports
#    - Step 2: Instantiate the environment and the Q-learning agent
#    - Step 3: Train the Q-learning RL agent
#    - Step 4: Plot the reward curves of the trained RL agent
#    - Step 5: Evaluate the trained Q-learning RL agent

# %% [markdown]
# #### Step 1: Add imports

# %%
import gymnasium as gym
import sys
import os
from dataclasses import asdict

sys.path.insert(1, "../")

from src.main.rl_agents.q_learning_agent import QLearningAgent
from src.main.configs.q_learning_agent_configs import QLearningAgentConfig
import src.main.configs.global_configs as configs
from src.main.utility.utils import Helpers
from src.main.evaluations.evaluate_agent import EvaluateAgent
from src.main.utility.chart_results import ChartResults

# %% [markdown]
# #### Step 2: Instantiate the environment and the Q-learning agent

# %%
q_learning_configs = asdict(QLearningAgentConfig())
q_learning_agent = QLearningAgent(**q_learning_configs)
# Out:
# 2025-06-08 20:53:10,838 - INFO - q_learning_agent.py:__init__ - : Frozen Lake environment creation.. in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\frozen-lake\src\main\rl_agents\q_learning_agent.py:55
# 2025-06-08 20:53:10,839 - INFO - q_learning_agent.py:__init__ - : Observation space: 16 in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\frozen-lake\src\main\rl_agents\q_learning_agent.py:56
# 2025-06-08 20:53:10,840 - INFO - q_learning_agent.py:__init__ - : Action space: 4 in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\frozen-lake\src\main\rl_agents\q_learning_agent.py:57
# 2025-06-08 20:53:10,840 - INFO - q_learning_agent.py:__init__ - : RL hyperparameters are:
#
# alpha: 0.1
#
# epsilon: 1.0
#
# ...

# %% [markdown]
# #### Step 3: Train the DQN RL agent

# %%
train_rewards = q_learning_agent.train()
Helpers.serialObject(q_learning_agent, configs.FROZEN_LAKE_QL_MODEL_FILE_PATH)
# Out:
# Training episodes::  12%|█▏        | 1233/10000 [00:00<00:03, 2219.14it/s]
# Episode 1000/10000  Average Reward: 0.211
#
# Q: [[4.02856903e-01 2.98578298e-01 2.83366050e-01 2.83934190e-01]
#  [4.69736851e-03 4.79957982e-02 2.62967121e-02 3.25234193e-01]
#  [2.66273816e-01 7.62091110e-03 2.01481421e-02 5.11314170e-04]
#  [0.00000000e+00 3.71856300e-03 0.00000000e+00 0.00000000e+00]
#  [4.18430557e-01 2.60366530e-01 2.05096680e-01 2.38802010e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [2.63552829e-01 5.96775255e-02 9.61173099e-04 1.22804475e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.18350501e-01 2.47536851e-01 1.64986614e-01 4.47323207e-01]
#  [3.16898423e-01 4.84751076e-01 1.01966040e-01 1.41082842e-01]
#  [5.47058725e-01 2.31547586e-01 2.32953654e-02 1.08013494e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# ...

# %% [markdown]
# #### Step 4: Plot the reward curves of the trained RL agent

# %%
ChartResults.plotRewardCurve(train_rewards, window_size=200)

# %% [markdown]
# #### Step 5: Evaluate the trained DQN RL agent

# %%
agent = Helpers.deserializeObject(configs.FROZEN_LAKE_QL_MODEL_FILE_PATH)
env = gym.make("FrozenLake-v1", is_slippery=True, render_mode="human")
rl_evaluator = EvaluateAgent(agent=agent, env=env, render_mode="human")
rl_evaluator.run()
