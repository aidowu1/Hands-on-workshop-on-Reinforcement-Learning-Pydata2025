# %% [markdown]
# ## Demo Cart-pole using DQN agent
#  - Demonstrates the Cart-pole problem
#  - A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track.
#    The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces in the left and right direction on the cart.
#  - The use of a DQN agent is used to balance the Cart-pole
#  - Steps of the solution include:
#    - Step 1: Add imports
#    - Step 2: Instantiate the environment and the DQN agent
#    - Step 3: Train the DQN RL agent
#    - Step 4: Plot the reward curves of the trained RL agent
#    - Step 5: Evaluate the trained DQN RL agent

# %% [markdown]
# #### Step 1: Add imports

# %%
import gymnasium as gym
import sys

sys.path.insert(1, "../")

import src.main.configs.global_configs as configs
import src.main.configs.global_configs as configs
from src.main.utility.utils import Helpers
from src.main.rl_algorithms.train_evaluate_test.dqn_algorithm import DQNTrainAlgorithm
from src.main.rl_algorithms.hyper_parameter_tuning.dqn_hyper_parameter_tuning import DQNHyperParameterTuning
from src.main.utility.enum_types import RLAgorithmType
from src.main.utility.chart_results import ChartResults

# %% [markdown]
# #### Step 2: Instantiate the environment and the DQN agent

# %%
cartpole_name = configs.CART_POLE_PROBLEM_NAME
env = gym.make(cartpole_name, render_mode="rgb_array")
rl_algorithm = RLAgorithmType.dqn
dqn_agent = DQNTrainAlgorithm(env)
# Out:
# 2025-06-08 13:37:13,314 - INFO - dqn_algorithm.py:__init__ - : Start of Reinforcement learning for environment: CARTPOLE-V1 in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\dqn_algorithm.py:47
# 2025-06-08 13:37:13,315 - INFO - dqn_algorithm.py:__init__ - : This RL environment uses a DQN RL algorithm agent in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\dqn_algorithm.py:48
# 2025-06-08 13:37:13,317 - INFO - base_algorithms.py:hyper_parameters - : Training is using non-tuned hyperparameters... in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\base_algorithms.py:116
# 2025-06-08 13:37:13,317 - INFO - base_algorithms.py:hyper_parameters - : Hyperparameters are:
# {'gamma': 0.9999, 'learning_rate': 0.0005, 'batch_size': 128, 'policy_kwargs': {'net_arch': [64, 64]}} in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\base_algorithms.py:117

# %% [markdown]
# #### Step 3: Train the DQN RL agent

# %%
dqn_agent.train()
# Out:
# 2025-06-08 13:37:16,337 - INFO - save_on_base_reward_callback.py:_init_callback - : Saving trained RL model to ./logs/CartPole-v1_dqn\best_model in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:45
# 2025-06-08 13:37:17,050 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 21.45
# 2025-06-08 13:37:17,852 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 2000
# Best mean reward: 21.45 - Last mean reward per episode: 21.61
# 2025-06-08 13:37:18,589 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 3000
# Best mean reward: 21.61 - Last mean reward per episode: 22.11
# 2025-06-08 13:37:19,426 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 4000
# Best mean reward: 22.11 - Last mean reward per episode: 23.76
# Num timesteps: 5000
# Best mean reward: 23.76 - Last mean reward per episode: 22.93
# Num timesteps: 6000
# Best mean reward: 23.76 - Last mean reward per episode: 19.21
# Num timesteps: 7000
# Best mean reward: 23.76 - Last mean reward per episode: 17.85
# Num timesteps: 8000
# Best mean reward: 23.76 - Last mean reward per episode: 18.06
# Num timesteps: 9000
# Best mean reward: 23.76 - Last mean reward per episode: 17.18
# Num timesteps: 10000
# Best mean reward: 23.76 - Last mean reward per episode: 17.46
# Eval num_timesteps=10000, episode_reward=9.40 +/- 1.02
# Episode length: 9.40 +/- 1.02
# New best mean reward!
# Num timesteps: 11000
# Best mean reward: 23.76 - Last mean reward per episode: 17.80
# Num timesteps: 12000
# Best mean reward: 23.76 - Last mean reward per episode: 18.16
# Num timesteps: 13000
# Best mean reward: 23.76 - Last mean reward per episode: 18.40
# Num timesteps: 14000
# Best mean reward: 23.76 - Last mean reward per episode: 17.13
# Num timesteps: 15000
# Best mean reward: 23.76 - Last mean reward per episode: 16.06
# Num timesteps: 16000
# Best mean reward: 23.76 - Last mean reward per episode: 16.61
# Num timesteps: 17000
# Best mean reward: 23.76 - Last mean reward per episode: 16.07
# Num timesteps: 18000
# Best mean reward: 23.76 - Last mean reward per episode: 16.60
# Num timesteps: 19000
# Best mean reward: 23.76 - Last mean reward per episode: 17.23
# Num timesteps: 20000
# Best mean reward: 23.76 - Last mean reward per episode: 17.59
# Eval num_timesteps=20000, episode_reward=16.20 +/- 1.94
# Episode length: 16.20 +/- 1.94
# New best mean reward!
# Num timesteps: 21000
# Best mean reward: 23.76 - Last mean reward per episode: 19.40
# Num timesteps: 22000
# Best mean reward: 23.76 - Last mean reward per episode: 21.93
# Num timesteps: 23000
# Best mean reward: 23.76 - Last mean reward per episode: 22.97
# 2025-06-08 13:37:34,408 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 24000
# Best mean reward: 23.76 - Last mean reward per episode: 23.78
# Num timesteps: 25000
# Best mean reward: 23.78 - Last mean reward per episode: 23.60
# Num timesteps: 26000
# Best mean reward: 23.78 - Last mean reward per episode: 22.63
# Num timesteps: 27000
# Best mean reward: 23.78 - Last mean reward per episode: 21.20
# Num timesteps: 28000
# Best mean reward: 23.78 - Last mean reward per episode: 21.75
# Num timesteps: 29000
# Best mean reward: 23.78 - Last mean reward per episode: 19.99
# Num timesteps: 30000
# Best mean reward: 23.78 - Last mean reward per episode: 19.86
# Eval num_timesteps=30000, episode_reward=20.60 +/- 6.28
# Episode length: 20.60 +/- 6.28
# New best mean reward!
# 2025-06-08 13:37:40,823 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 31000
# Best mean reward: 23.78 - Last mean reward per episode: 25.04
# 2025-06-08 13:37:41,923 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 32000
# Best mean reward: 25.04 - Last mean reward per episode: 28.82
# 2025-06-08 13:37:43,056 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 33000
# Best mean reward: 28.82 - Last mean reward per episode: 31.88
# Num timesteps: 34000
# Best mean reward: 31.88 - Last mean reward per episode: 30.46
# Num timesteps: 35000
# Best mean reward: 31.88 - Last mean reward per episode: 29.67
# Num timesteps: 36000
# Best mean reward: 31.88 - Last mean reward per episode: 29.04
# Num timesteps: 37000
# Best mean reward: 31.88 - Last mean reward per episode: 29.60
# Num timesteps: 38000
# Best mean reward: 31.88 - Last mean reward per episode: 30.37
# 2025-06-08 13:37:47,900 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 39000
# Best mean reward: 31.88 - Last mean reward per episode: 32.15
# 2025-06-08 13:37:48,790 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 40000
# Best mean reward: 32.15 - Last mean reward per episode: 33.24
# Eval num_timesteps=40000, episode_reward=49.00 +/- 13.25
# Episode length: 49.00 +/- 13.25
# New best mean reward!
# 2025-06-08 13:37:49,689 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 41000
# Best mean reward: 33.24 - Last mean reward per episode: 38.34
# 2025-06-08 13:37:50,503 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 42000
# Best mean reward: 38.34 - Last mean reward per episode: 44.98
# 2025-06-08 13:37:51,329 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 43000
# Best mean reward: 44.98 - Last mean reward per episode: 49.46
# 2025-06-08 13:37:52,162 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 44000
# Best mean reward: 49.46 - Last mean reward per episode: 53.88
# 2025-06-08 13:37:53,025 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 45000
# Best mean reward: 53.88 - Last mean reward per episode: 58.18
# 2025-06-08 13:37:53,878 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 46000
# Best mean reward: 58.18 - Last mean reward per episode: 62.43
# Num timesteps: 47000
# Best mean reward: 62.43 - Last mean reward per episode: 59.22
# Num timesteps: 48000
# Best mean reward: 62.43 - Last mean reward per episode: 58.58
# Num timesteps: 49000
# Best mean reward: 62.43 - Last mean reward per episode: 58.38
# 2025-06-08 13:37:57,050 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 50000
# Best mean reward: 62.43 - Last mean reward per episode: 62.55
# Eval num_timesteps=50000, episode_reward=30.60 +/- 12.77
# Episode length: 30.60 +/- 12.77
# 2025-06-08 13:37:57,915 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 51000
# Best mean reward: 62.55 - Last mean reward per episode: 64.62
# 2025-06-08 13:37:58,746 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 52000
# Best mean reward: 64.62 - Last mean reward per episode: 69.89
# 2025-06-08 13:37:59,548 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 53000
# Best mean reward: 69.89 - Last mean reward per episode: 75.32
# 2025-06-08 13:38:00,378 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 54000
# Best mean reward: 75.32 - Last mean reward per episode: 82.87
# 2025-06-08 13:38:01,195 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 55000
# Best mean reward: 82.87 - Last mean reward per episode: 87.39
# 2025-06-08 13:38:02,130 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 56000
# Best mean reward: 87.39 - Last mean reward per episode: 95.19
# 2025-06-08 13:38:02,987 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 57000
# Best mean reward: 95.19 - Last mean reward per episode: 101.70
# 2025-06-08 13:38:03,825 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 58000
# Best mean reward: 101.70 - Last mean reward per episode: 104.20
# 2025-06-08 13:38:04,700 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 59000
# Best mean reward: 104.20 - Last mean reward per episode: 109.72
# 2025-06-08 13:38:05,643 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 60000
# Best mean reward: 109.72 - Last mean reward per episode: 113.53
# Eval num_timesteps=60000, episode_reward=122.60 +/- 48.79
# Episode length: 122.60 +/- 48.79
# New best mean reward!
# 2025-06-08 13:38:06,663 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 61000
# Best mean reward: 113.53 - Last mean reward per episode: 122.89
# 2025-06-08 13:38:07,480 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 62000
# Best mean reward: 122.89 - Last mean reward per episode: 127.83
# 2025-06-08 13:38:08,332 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 63000
# Best mean reward: 127.83 - Last mean reward per episode: 132.43
# 2025-06-08 13:38:09,196 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 64000
# Best mean reward: 132.43 - Last mean reward per episode: 142.24
# 2025-06-08 13:38:09,986 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 65000
# Best mean reward: 142.24 - Last mean reward per episode: 149.20
# 2025-06-08 13:38:10,821 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 66000
# Best mean reward: 149.20 - Last mean reward per episode: 155.95
# 2025-06-08 13:38:11,632 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 67000
# Best mean reward: 155.95 - Last mean reward per episode: 160.55
# 2025-06-08 13:38:12,430 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 68000
# Best mean reward: 160.55 - Last mean reward per episode: 163.38
# 2025-06-08 13:38:13,279 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 69000
# Best mean reward: 163.38 - Last mean reward per episode: 168.52
# 2025-06-08 13:38:14,110 - INFO - save_on_base_reward_callback.py:_on_step - : Saving new best model to ./logs/CartPole-v1_dqn\best_model.zip in C:\Development\Python\AI\ReinforcementLearning\PyData2025-Presentation\repo\Hands-on-workshop-on-Reinforcement-Learning-Pydata2025\demos\cart-pole\src\main\rl_algorithms\train_evaluate_test\save_on_base_reward_callback.py:66
# Num timesteps: 70000
# Best mean reward: 168.52 - Last mean reward per episode: 169.97
# Eval num_timesteps=70000, episode_reward=232.40 +/- 123.08
# Episode length: 232.40 +/- 123.08
# New best mean reward!
# Stopping training because the mean reward 232.40  is above the threshold 200

# %% [markdown]
# #### Step 4: Plot the reward curves of the trained RL agent

# %%
rewards = Helpers.getSmoothedAverageRewards(
    env_name=cartpole_name,
    rl_algo_name=rl_algorithm.name
)
ChartResults.plotRewardCurve(rewards, window_size=200)

# %% [markdown]
# #### Step 5: Evaluate the trained DQN RL agent

# %%
eval_env = gym.make(cartpole_name, render_mode="human")
eval_rewards = dqn_agent.evaluate(env=eval_env)
